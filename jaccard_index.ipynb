# %% [markdown]
# # Similaridade de Jaccard

# %% [markdown]
# ## Configurações iniciais

# %%
import os.path
import pandas as pd

# Diretório base dos datasets
base_dir = './data/02-cleaned/'

# Dicionários de datasets
datasets_path = {
		'Fortuna'     :os.path.join(base_dir, 'fortuna.csv'),
		'HateBRXplain':os.path.join(base_dir, 'hatebrxplain.csv'),
		'OffComBR'    :os.path.join(base_dir, 'offcombr3.csv'),
		'OLID-BR'     :os.path.join(base_dir, 'olidbr.csv'),
		'ToLD-BR'     :os.path.join(base_dir, 'toldbr.csv'),
		'TuPy'        :os.path.join(base_dir, 'tupy.csv')
		}

datasets_df = {
		'Fortuna'     :pd.read_csv(datasets_path['Fortuna']),
		'HateBRXplain':pd.read_csv(datasets_path['HateBRXplain']),
		'OffComBR'    :pd.read_csv(datasets_path['OffComBR']),
		'OLID-BR'     :pd.read_csv(datasets_path['OLID-BR']),
		'ToLD-BR'     :pd.read_csv(datasets_path['ToLD-BR']),
		'TuPy'        :pd.read_csv(datasets_path['TuPy'])
		}

# %%
def get_jaccard_index(df1, df2, col_text='text'):
    # 1. Convert to string and lowercase (.str.lower())
    # 2. Join everything into a single text (.str.cat)
    # 3. Split by spaces to get the words (.split)
    words_a = df1[col_text].astype(str).str.lower().str.cat(sep=' ').split()
    words_b = df2[col_text].astype(str).str.lower().str.cat(sep=' ').split()

    # Create sets of unique words
    vocab_a = set(words_a)
    vocab_b = set(words_b)

    # Calculations
    intersection = vocab_a.intersection(vocab_b)
    union = vocab_a.union(vocab_b)

    jaccard = len(intersection) / len(union) if len(union) > 0 else 0.0

    return jaccard, len(intersection), len(union)

# %% [markdown]
# ## Similaridade de Jaccard para o dataset completo

# %%
# 1. Get the list of dataset names
dataset_names = list(datasets_df.keys())
jaccard_matrix = []

print("Calculating Jaccard Similarity Matrix...")

# 2. Nested loop to compare every dataset against every other dataset
for name_a in dataset_names:
    row_scores = []
    # print(f"Processing: {name_a}...") # Optional: to track progress

    for name_b in dataset_names:
        # Calculate Jaccard index (unpacking the tuple to get just the score)
        score, intersection_count, union_count = get_jaccard_index(datasets_df[name_a], datasets_df[name_b])
        row_scores.append(score)

    jaccard_matrix.append(row_scores)

# 3. Create the final DataFrame
jaccard_df = pd.DataFrame(jaccard_matrix, index=dataset_names, columns=dataset_names)

print("Done!")

# 4. Display with a heatmap for better visualization
jaccard_df.style.background_gradient(cmap='Greens', axis=None).format("{:.2%}")
# Out:
# Calculating Jaccard Similarity Matrix...
# Done!
# <style type="text/css">
# #T_6938d_row0_col0, #T_6938d_row1_col1, #T_6938d_row2_col2, #T_6938d_row3_col3, #T_6938d_row4_col4, #T_6938d_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_6938d_row0_col1, #T_6938d_row1_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_6938d_row0_col2, #T_6938d_row1_col2, #T_6938d_row2_col0, #T_6938d_row2_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_6938d_row0_col3, #T_6938d_row3_col0 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_6938d_row0_col4, #T_6938d_row4_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_6938d_row0_col5, #T_6938d_row1_col3, #T_6938d_row3_col1, #T_6938d_row5_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_6938d_row1_col4, #T_6938d_row4_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_6938d_row1_col5, #T_6938d_row5_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_6938d_row2_col3, #T_6938d_row3_col2 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_6938d_row2_col4, #T_6938d_row4_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_6938d_row2_col5, #T_6938d_row5_col2 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_6938d_row3_col4, #T_6938d_row3_col5, #T_6938d_row4_col3, #T_6938d_row5_col3 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_6938d_row4_col5, #T_6938d_row5_col4 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# </style>
# <table id="T_6938d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6938d_level0_col0" class="col_heading level0 col0" >Fortuna</th>
#       <th id="T_6938d_level0_col1" class="col_heading level0 col1" >HateBRXplain</th>
#       <th id="T_6938d_level0_col2" class="col_heading level0 col2" >OffComBR</th>
#       <th id="T_6938d_level0_col3" class="col_heading level0 col3" >OLID-BR</th>
#       <th id="T_6938d_level0_col4" class="col_heading level0 col4" >ToLD-BR</th>
#       <th id="T_6938d_level0_col5" class="col_heading level0 col5" >TuPy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6938d_level0_row0" class="row_heading level0 row0" >Fortuna</th>
#       <td id="T_6938d_row0_col0" class="data row0 col0" >100.00%</td>
#       <td id="T_6938d_row0_col1" class="data row0 col1" >17.32%</td>
#       <td id="T_6938d_row0_col2" class="data row0 col2" >9.00%</td>
#       <td id="T_6938d_row0_col3" class="data row0 col3" >18.15%</td>
#       <td id="T_6938d_row0_col4" class="data row0 col4" >16.64%</td>
#       <td id="T_6938d_row0_col5" class="data row0 col5" >18.46%</td>
#     </tr>
#     <tr>
#       <th id="T_6938d_level0_row1" class="row_heading level0 row1" >HateBRXplain</th>
#       <td id="T_6938d_row1_col0" class="data row1 col0" >17.32%</td>
#       <td id="T_6938d_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_6938d_row1_col2" class="data row1 col2" >8.99%</td>
#       <td id="T_6938d_row1_col3" class="data row1 col3" >18.56%</td>
#       <td id="T_6938d_row1_col4" class="data row1 col4" >16.02%</td>
#       <td id="T_6938d_row1_col5" class="data row1 col5" >17.95%</td>
#     </tr>
#     <tr>
#       <th id="T_6938d_level0_row2" class="row_heading level0 row2" >OffComBR</th>
#       <td id="T_6938d_row2_col0" class="data row2 col0" >9.00%</td>
#       <td id="T_6938d_row2_col1" class="data row2 col1" >8.99%</td>
#       <td id="T_6938d_row2_col2" class="data row2 col2" >100.00%</td>
#       <td id="T_6938d_row2_col3" class="data row2 col3" >7.77%</td>
#       <td id="T_6938d_row2_col4" class="data row2 col4" >5.94%</td>
#       <td id="T_6938d_row2_col5" class="data row2 col5" >8.20%</td>
#     </tr>
#     <tr>
#       <th id="T_6938d_level0_row3" class="row_heading level0 row3" >OLID-BR</th>
#       <td id="T_6938d_row3_col0" class="data row3 col0" >18.15%</td>
#       <td id="T_6938d_row3_col1" class="data row3 col1" >18.56%</td>
#       <td id="T_6938d_row3_col2" class="data row3 col2" >7.77%</td>
#       <td id="T_6938d_row3_col3" class="data row3 col3" >100.00%</td>
#       <td id="T_6938d_row3_col4" class="data row3 col4" >19.89%</td>
#       <td id="T_6938d_row3_col5" class="data row3 col5" >19.82%</td>
#     </tr>
#     <tr>
#       <th id="T_6938d_level0_row4" class="row_heading level0 row4" >ToLD-BR</th>
#       <td id="T_6938d_row4_col0" class="data row4 col0" >16.64%</td>
#       <td id="T_6938d_row4_col1" class="data row4 col1" >16.02%</td>
#       <td id="T_6938d_row4_col2" class="data row4 col2" >5.94%</td>
#       <td id="T_6938d_row4_col3" class="data row4 col3" >19.89%</td>
#       <td id="T_6938d_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_6938d_row4_col5" class="data row4 col5" >20.71%</td>
#     </tr>
#     <tr>
#       <th id="T_6938d_level0_row5" class="row_heading level0 row5" >TuPy</th>
#       <td id="T_6938d_row5_col0" class="data row5 col0" >18.46%</td>
#       <td id="T_6938d_row5_col1" class="data row5 col1" >17.95%</td>
#       <td id="T_6938d_row5_col2" class="data row5 col2" >8.20%</td>
#       <td id="T_6938d_row5_col3" class="data row5 col3" >19.82%</td>
#       <td id="T_6938d_row5_col4" class="data row5 col4" >20.71%</td>
#       <td id="T_6938d_row5_col5" class="data row5 col5" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Similaridade de Jaccard para TOXIC

# %%
# 1. Get the list of dataset names
dataset_names = list(datasets_df.keys())
jaccard_matrix = []

print("Calculating Jaccard Similarity Matrix (Toxic Only)...")

# 2. Nested loop to compare every dataset against every other dataset
for name_a in dataset_names:
    row_scores = []

    # Filter Dataset A: Keep only rows where is_toxic is True (1)
    df_a = datasets_df[name_a]
    toxic_subset_a = df_a[df_a['is_toxic'] == True]

    for name_b in dataset_names:
        # Filter Dataset B: Keep only rows where is_toxic is True (1)
        df_b = datasets_df[name_b]
        toxic_subset_b = df_b[df_b['is_toxic'] == True]

        # Calculate Jaccard index using ONLY the toxic subsets
        score, intersection_count, union_count = get_jaccard_index(toxic_subset_a, toxic_subset_b)
        row_scores.append(score)

    jaccard_matrix.append(row_scores)

# 3. Create the final DataFrame
jaccard_df = pd.DataFrame(jaccard_matrix, index=dataset_names, columns=dataset_names)

print("Done!")

# 4. Display with a heatmap for better visualization
jaccard_df.style.background_gradient(cmap='Greens', axis=None).format("{:.2%}")
# Out:
# Calculating Jaccard Similarity Matrix (Toxic Only)...
# Done!
# <style type="text/css">
# #T_230e8_row0_col0, #T_230e8_row1_col1, #T_230e8_row2_col2, #T_230e8_row3_col3, #T_230e8_row4_col4, #T_230e8_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_230e8_row0_col1, #T_230e8_row1_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_230e8_row0_col2, #T_230e8_row2_col0 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_230e8_row0_col3, #T_230e8_row3_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_230e8_row0_col4, #T_230e8_row4_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_230e8_row0_col5, #T_230e8_row1_col4, #T_230e8_row1_col5, #T_230e8_row4_col1, #T_230e8_row5_col0, #T_230e8_row5_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_230e8_row1_col2, #T_230e8_row2_col1, #T_230e8_row2_col4, #T_230e8_row4_col2 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_230e8_row1_col3, #T_230e8_row3_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_230e8_row2_col3, #T_230e8_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_230e8_row2_col5, #T_230e8_row5_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_230e8_row3_col4, #T_230e8_row4_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_230e8_row3_col5, #T_230e8_row5_col3 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_230e8_row4_col5, #T_230e8_row5_col4 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# </style>
# <table id="T_230e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_230e8_level0_col0" class="col_heading level0 col0" >Fortuna</th>
#       <th id="T_230e8_level0_col1" class="col_heading level0 col1" >HateBRXplain</th>
#       <th id="T_230e8_level0_col2" class="col_heading level0 col2" >OffComBR</th>
#       <th id="T_230e8_level0_col3" class="col_heading level0 col3" >OLID-BR</th>
#       <th id="T_230e8_level0_col4" class="col_heading level0 col4" >ToLD-BR</th>
#       <th id="T_230e8_level0_col5" class="col_heading level0 col5" >TuPy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_230e8_level0_row0" class="row_heading level0 row0" >Fortuna</th>
#       <td id="T_230e8_row0_col0" class="data row0 col0" >100.00%</td>
#       <td id="T_230e8_row0_col1" class="data row0 col1" >15.85%</td>
#       <td id="T_230e8_row0_col2" class="data row0 col2" >5.73%</td>
#       <td id="T_230e8_row0_col3" class="data row0 col3" >14.07%</td>
#       <td id="T_230e8_row0_col4" class="data row0 col4" >16.14%</td>
#       <td id="T_230e8_row0_col5" class="data row0 col5" >16.95%</td>
#     </tr>
#     <tr>
#       <th id="T_230e8_level0_row1" class="row_heading level0 row1" >HateBRXplain</th>
#       <td id="T_230e8_row1_col0" class="data row1 col0" >15.85%</td>
#       <td id="T_230e8_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_230e8_row1_col2" class="data row1 col2" >4.16%</td>
#       <td id="T_230e8_row1_col3" class="data row1 col3" >17.28%</td>
#       <td id="T_230e8_row1_col4" class="data row1 col4" >16.86%</td>
#       <td id="T_230e8_row1_col5" class="data row1 col5" >16.86%</td>
#     </tr>
#     <tr>
#       <th id="T_230e8_level0_row2" class="row_heading level0 row2" >OffComBR</th>
#       <td id="T_230e8_row2_col0" class="data row2 col0" >5.73%</td>
#       <td id="T_230e8_row2_col1" class="data row2 col1" >4.16%</td>
#       <td id="T_230e8_row2_col2" class="data row2 col2" >100.00%</td>
#       <td id="T_230e8_row2_col3" class="data row2 col3" >2.66%</td>
#       <td id="T_230e8_row2_col4" class="data row2 col4" >3.88%</td>
#       <td id="T_230e8_row2_col5" class="data row2 col5" >6.98%</td>
#     </tr>
#     <tr>
#       <th id="T_230e8_level0_row3" class="row_heading level0 row3" >OLID-BR</th>
#       <td id="T_230e8_row3_col0" class="data row3 col0" >14.07%</td>
#       <td id="T_230e8_row3_col1" class="data row3 col1" >17.28%</td>
#       <td id="T_230e8_row3_col2" class="data row3 col2" >2.66%</td>
#       <td id="T_230e8_row3_col3" class="data row3 col3" >100.00%</td>
#       <td id="T_230e8_row3_col4" class="data row3 col4" >19.95%</td>
#       <td id="T_230e8_row3_col5" class="data row3 col5" >12.81%</td>
#     </tr>
#     <tr>
#       <th id="T_230e8_level0_row4" class="row_heading level0 row4" >ToLD-BR</th>
#       <td id="T_230e8_row4_col0" class="data row4 col0" >16.14%</td>
#       <td id="T_230e8_row4_col1" class="data row4 col1" >16.86%</td>
#       <td id="T_230e8_row4_col2" class="data row4 col2" >3.88%</td>
#       <td id="T_230e8_row4_col3" class="data row4 col3" >19.95%</td>
#       <td id="T_230e8_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_230e8_row4_col5" class="data row4 col5" >15.45%</td>
#     </tr>
#     <tr>
#       <th id="T_230e8_level0_row5" class="row_heading level0 row5" >TuPy</th>
#       <td id="T_230e8_row5_col0" class="data row5 col0" >16.95%</td>
#       <td id="T_230e8_row5_col1" class="data row5 col1" >16.86%</td>
#       <td id="T_230e8_row5_col2" class="data row5 col2" >6.98%</td>
#       <td id="T_230e8_row5_col3" class="data row5 col3" >12.81%</td>
#       <td id="T_230e8_row5_col4" class="data row5 col4" >15.45%</td>
#       <td id="T_230e8_row5_col5" class="data row5 col5" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Similaridade de Jaccard para NON-TOXIC

# %%
import pandas as pd

# 1. Get the list of dataset names
dataset_names = list(datasets_df.keys())
jaccard_matrix = []

print("Calculating Jaccard Similarity Matrix (Non-toxic Only)...")

# 2. Nested loop to compare every dataset against every other dataset
for name_a in dataset_names:
    row_scores = []

    # Filter Dataset A: Keep only rows where is_toxic is False (0)
    df_a = datasets_df[name_a]
    toxic_subset_a = df_a[df_a['is_toxic'] == False]

    for name_b in dataset_names:
        # Filter Dataset B: Keep only rows where is_toxic is False (0)
        df_b = datasets_df[name_b]
        toxic_subset_b = df_b[df_b['is_toxic'] == False]

        # Calculate Jaccard index using ONLY the toxic subsets
        score, intersection_count, union_count = get_jaccard_index(toxic_subset_a, toxic_subset_b)
        row_scores.append(score)

    jaccard_matrix.append(row_scores)

# 3. Create the final DataFrame
jaccard_df = pd.DataFrame(jaccard_matrix, index=dataset_names, columns=dataset_names)

print("Done!")

# 4. Display with a heatmap for better visualization
jaccard_df.style.background_gradient(cmap='Greens', axis=None).format("{:.2%}")
# Out:
# Calculating Jaccard Similarity Matrix (Non-toxic Only)...
# Done!
# <style type="text/css">
# #T_cde9b_row0_col0, #T_cde9b_row1_col1, #T_cde9b_row2_col2, #T_cde9b_row3_col3, #T_cde9b_row4_col4, #T_cde9b_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_cde9b_row0_col1, #T_cde9b_row0_col4, #T_cde9b_row1_col0, #T_cde9b_row4_col0 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_cde9b_row0_col2, #T_cde9b_row2_col0 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_cde9b_row0_col3, #T_cde9b_row1_col3, #T_cde9b_row3_col0, #T_cde9b_row3_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_cde9b_row0_col5, #T_cde9b_row5_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_cde9b_row1_col2, #T_cde9b_row2_col1, #T_cde9b_row3_col4, #T_cde9b_row4_col3 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_cde9b_row1_col4, #T_cde9b_row2_col3, #T_cde9b_row3_col2, #T_cde9b_row4_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_cde9b_row1_col5, #T_cde9b_row5_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_cde9b_row2_col4, #T_cde9b_row4_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_cde9b_row2_col5, #T_cde9b_row5_col2 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_cde9b_row3_col5, #T_cde9b_row5_col3 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_cde9b_row4_col5, #T_cde9b_row5_col4 {
#   background-color: #def2d9;
#   color: #000000;
# }
# </style>
# <table id="T_cde9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cde9b_level0_col0" class="col_heading level0 col0" >Fortuna</th>
#       <th id="T_cde9b_level0_col1" class="col_heading level0 col1" >HateBRXplain</th>
#       <th id="T_cde9b_level0_col2" class="col_heading level0 col2" >OffComBR</th>
#       <th id="T_cde9b_level0_col3" class="col_heading level0 col3" >OLID-BR</th>
#       <th id="T_cde9b_level0_col4" class="col_heading level0 col4" >ToLD-BR</th>
#       <th id="T_cde9b_level0_col5" class="col_heading level0 col5" >TuPy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cde9b_level0_row0" class="row_heading level0 row0" >Fortuna</th>
#       <td id="T_cde9b_row0_col0" class="data row0 col0" >100.00%</td>
#       <td id="T_cde9b_row0_col1" class="data row0 col1" >15.80%</td>
#       <td id="T_cde9b_row0_col2" class="data row0 col2" >9.52%</td>
#       <td id="T_cde9b_row0_col3" class="data row0 col3" >15.10%</td>
#       <td id="T_cde9b_row0_col4" class="data row0 col4" >15.89%</td>
#       <td id="T_cde9b_row0_col5" class="data row0 col5" >17.24%</td>
#     </tr>
#     <tr>
#       <th id="T_cde9b_level0_row1" class="row_heading level0 row1" >HateBRXplain</th>
#       <td id="T_cde9b_row1_col0" class="data row1 col0" >15.80%</td>
#       <td id="T_cde9b_row1_col1" class="data row1 col1" >100.00%</td>
#       <td id="T_cde9b_row1_col2" class="data row1 col2" >10.76%</td>
#       <td id="T_cde9b_row1_col3" class="data row1 col3" >15.50%</td>
#       <td id="T_cde9b_row1_col4" class="data row1 col4" >13.21%</td>
#       <td id="T_cde9b_row1_col5" class="data row1 col5" >14.75%</td>
#     </tr>
#     <tr>
#       <th id="T_cde9b_level0_row2" class="row_heading level0 row2" >OffComBR</th>
#       <td id="T_cde9b_row2_col0" class="data row2 col0" >9.52%</td>
#       <td id="T_cde9b_row2_col1" class="data row2 col1" >10.76%</td>
#       <td id="T_cde9b_row2_col2" class="data row2 col2" >100.00%</td>
#       <td id="T_cde9b_row2_col3" class="data row2 col3" >13.49%</td>
#       <td id="T_cde9b_row2_col4" class="data row2 col4" >6.22%</td>
#       <td id="T_cde9b_row2_col5" class="data row2 col5" >8.01%</td>
#     </tr>
#     <tr>
#       <th id="T_cde9b_level0_row3" class="row_heading level0 row3" >OLID-BR</th>
#       <td id="T_cde9b_row3_col0" class="data row3 col0" >15.10%</td>
#       <td id="T_cde9b_row3_col1" class="data row3 col1" >15.50%</td>
#       <td id="T_cde9b_row3_col2" class="data row3 col2" >13.49%</td>
#       <td id="T_cde9b_row3_col3" class="data row3 col3" >100.00%</td>
#       <td id="T_cde9b_row3_col4" class="data row3 col4" >10.88%</td>
#       <td id="T_cde9b_row3_col5" class="data row3 col5" >12.86%</td>
#     </tr>
#     <tr>
#       <th id="T_cde9b_level0_row4" class="row_heading level0 row4" >ToLD-BR</th>
#       <td id="T_cde9b_row4_col0" class="data row4 col0" >15.89%</td>
#       <td id="T_cde9b_row4_col1" class="data row4 col1" >13.21%</td>
#       <td id="T_cde9b_row4_col2" class="data row4 col2" >6.22%</td>
#       <td id="T_cde9b_row4_col3" class="data row4 col3" >10.88%</td>
#       <td id="T_cde9b_row4_col4" class="data row4 col4" >100.00%</td>
#       <td id="T_cde9b_row4_col5" class="data row4 col5" >20.66%</td>
#     </tr>
#     <tr>
#       <th id="T_cde9b_level0_row5" class="row_heading level0 row5" >TuPy</th>
#       <td id="T_cde9b_row5_col0" class="data row5 col0" >17.24%</td>
#       <td id="T_cde9b_row5_col1" class="data row5 col1" >14.75%</td>
#       <td id="T_cde9b_row5_col2" class="data row5 col2" >8.01%</td>
#       <td id="T_cde9b_row5_col3" class="data row5 col3" >12.86%</td>
#       <td id="T_cde9b_row5_col4" class="data row5 col4" >20.66%</td>
#       <td id="T_cde9b_row5_col5" class="data row5 col5" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
